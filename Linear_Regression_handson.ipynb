# %% [markdown]
# The process of finding the relationship between independent variable and dependent variable.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
insurance=pd.read_csv('/content/new_insurance_data (1).csv')

# %%
insurance
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
# ...

# %%
insurance.head()
# Out:
#     age   sex    bmi  children smoker  Claim_Amount  past_consultations  \
# 0  18.0  male  23.21       0.0     no   29087.54313                17.0
# 1  18.0  male  30.14       0.0     no   39053.67437                 7.0
# 2  18.0  male  33.33       0.0     no   39023.62759                19.0
# 3  18.0  male  33.66       0.0     no   28185.39332                11.0
# 4  18.0  male  34.10       0.0     no   14697.85941                16.0
#
#    num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0      715428.0           4720920.992                              0.0
# 1      699157.0           4329831.676                              0.0
# 2      702341.0           6884860.774                              0.0
# 3      700250.0           4274773.550                              0.0
# 4      711584.0           3787293.921                              0.0
#
#    Anual_Salary     region    charges
# 0   55784970.05  southeast  1121.8739
# ...

# %%
insurance.tail()
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 1333     1091267.0           170380500.5                              2.0
# 1334     1107872.0           201515184.8                              2.0
# 1335     1092005.0           223644981.3                              2.0
# 1336     1106821.0           252892382.6                              3.0
# 1337     1100328.0           261631699.3                              3.0
#
#       Anual_Salary     region      charges
# ...

# %%
# we always check the top order as well as bottom order to check the values are in same format or not,two data's are merged together like 1,2,3,can be changed to one,two ,three while merging

# %%
#checking the rows and columns of the data
insurance.shape
# Out:
# (1338, 13)

# %%
insurance.shape[0] #rows
# Out:
# 1338

# %%
insurance.shape[1]#columns
# Out:
# 13

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
# ...

# %%
insurance.isnull()
# Out:
#         age    sex    bmi  children  smoker  Claim_Amount  past_consultations  \
# 0     False  False  False     False   False         False               False
# 1     False  False  False     False   False         False               False
# 2     False  False  False     False   False         False               False
# 3     False  False  False     False   False         False               False
# 4     False  False  False     False   False         False               False
# ...     ...    ...    ...       ...     ...           ...                 ...
# 1333  False  False  False     False   False         False               False
# 1334  False  False  False     False   False         False               False
# 1335  False  False  False     False   False         False               False
# 1336  False  False  False     False   False         False               False
# 1337  False  False  False     False   False         False               False
#
# ...

# %%
insurance.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
insurance.isnull().sum().sum()             #total 52 null values we have in our data
# Out:
# 52

# %%
insurance.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %%
col=list(insurance.columns)

# %%
col
# Out:
# ['age',
#  'sex',
#  'bmi',
#  'children',
#  'smoker',
#  'Claim_Amount',
#  'past_consultations',
#  'num_of_steps',
#  'Hospital_expenditure',
#  'NUmber_of_past_hospitalizations',
#  'Anual_Salary',
#  'region',
#  'charges']

# %%
#discrete:limited number  of outputs.Ex Roll of dice
#continoutous:Increasing amount of data.(range of datasets)
#Replacing null values with mean:numerical  or mode(object data types like smoker ,sex,region)

# %%
insurance['smoker'].mode()
# Out:
# 0    no
# Name: smoker, dtype: object

# %%
insurance['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64

# %%
insurance['smoker'].mode()[0]   #we don't need extra information
# Out:
# 'no'

# %%
insurance['age'].mean()
# Out:
# 39.31000752445448

# %%
for col_name in col:
  if insurance[col_name].dtype=='object':
    insurance[col_name]=insurance[col_name].fillna(insurance[col_name].mode([0]))
  else:
    insurance[col_name]=insurance[col_name].fillna(insurance[col_name].mean())

# %%
insurance.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
for col_name in col:
  if (insurance[col_name].dtype=='int64' or insurance[col_name].dtype=='float64'):
    plt.boxplot(insurance[col_name])
    plt.xlabel(col_name)
    plt.ylabel('count')
    plt.show()

# %%
col
# Out:
# ['age',
#  'sex',
#  'bmi',
#  'children',
#  'smoker',
#  'Claim_Amount',
#  'past_consultations',
#  'num_of_steps',
#  'Hospital_expenditure',
#  'NUmber_of_past_hospitalizations',
#  'Anual_Salary',
#  'region',
#  'charges']

# %%
q1=insurance['bmi'].quantile(0.25)
q3=insurance['bmi'].quantile(0.75)
iqr=q3-q1
insurance=insurance[(insurance['bmi']>(q1-1.5*iqr))|(insurance['bmi']<(q3+1.5*iqr))]

q1=insurance['past_consultations'].quantile(0.25)
q3=insurance['past_consultations'].quantile(0.75)
iqr=q3-q1
insurance=insurance[(insurance['past_consultations']>(q1-1.5*iqr))|(insurance['past_consultations']<(q3+1.5*iqr))]


q1=insurance['Hospital_expenditure'].quantile(0.25)
q3=insurance['Hospital_expenditure'].quantile(0.75)
iqr=q3-q1
insurance=insurance[(insurance['Hospital_expenditure']>(q1-1.5*iqr))|(insurance['Hospital_expenditure']<(q3+1.5*iqr))]

# %%
insurance.shape
# Out:
# (1338, 13)

# %%
for col_name in col:
  if (insurance[col_name].dtype=='int64' or insurance[col_name].dtype=='float64'):
    plt.boxplot(insurance[col_name])
    plt.xlabel(col_name)
    plt.ylabel('count')
    plt.show()

# %%
#after removing outlier we still have the outlier Home work

# %%
insurance.corr(numeric_only=True)
# Out:
#                                       age       bmi  children  Claim_Amount  \
# age                              1.000000  0.112161  0.041448      0.122828
# bmi                              0.112161  1.000000  0.007923      0.093313
# children                         0.041448  0.007923  1.000000      0.041276
# Claim_Amount                     0.122828  0.093313  0.041276      1.000000
# past_consultations               0.168311  0.130667  0.054688      0.271482
# num_of_steps                     0.512985  0.135903  0.163307      0.398342
# Hospital_expenditure             0.136710  0.256858  0.025128      0.370310
# NUmber_of_past_hospitalizations  0.359391  0.137060  0.185505      0.379731
# Anual_Salary                     0.163540  0.241502  0.039983      0.403925
# charges                          0.293604  0.198691  0.070686      0.435635
#
#                                  past_consultations  num_of_steps  \
# ...

# %%
#Which column will be affected in model building

# %%
#We have VIF variation inflation factor ,we include that column having value less than <6 and remove that column having value greater than >6.

# %%
#with change in age num_of_steps is changing so there is no rigidity.so we have to drop the columns then which columns age or num_of_steps.By this rule we calculate VIF

# %%
col_list=[]
for i in insurance.columns:
  if((insurance[i].dtype!='object')& (i!='charges')):
    col_list.append(i)

# %%
col_list
# Out:
# ['age',
#  'bmi',
#  'children',
#  'Claim_Amount',
#  'past_consultations',
#  'num_of_steps',
#  'Hospital_expenditure',
#  'NUmber_of_past_hospitalizations',
#  'Anual_Salary']

# %%
X=insurance[col_list]

# %%
X
# Out:
#        age     bmi  children  Claim_Amount  past_consultations  num_of_steps  \
# 0     18.0  23.210       0.0   29087.54313                17.0      715428.0
# 1     18.0  30.140       0.0   39053.67437                 7.0      699157.0
# 2     18.0  33.330       0.0   39023.62759                19.0      702341.0
# 3     18.0  33.660       0.0   28185.39332                11.0      700250.0
# 4     18.0  34.100       0.0   14697.85941                16.0      711584.0
# ...    ...     ...       ...           ...                 ...           ...
# 1333  33.0  35.530       0.0   63142.25346                32.0     1091267.0
# 1334  31.0  38.095       1.0   43419.95227                31.0     1107872.0
# 1335  52.0  34.485       3.0   52458.92353                25.0     1092005.0
# 1336  45.0  30.360       0.0   69927.51664                34.0     1106821.0
# 1337  54.0  47.410       0.0   63982.80926                31.0     1100328.0
#
# ...

# %%
X.columns
# Out:
# Index(['age', 'bmi', 'children', 'Claim_Amount', 'past_consultations',
#        'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary'],
#       dtype='object')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for i in insurance.columns:
  if((insurance[i].dtype!='object')& (i!='charges')):
    col_list.append(i)

X=insurance[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values , i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#                            feature        VIF
# 0                              age  11.972236
# 1                              bmi  26.048801
# 2                         children   1.950345
# 3                     Claim_Amount   6.914689
# 4               past_consultations   8.359097
# 5                     num_of_steps  60.081218
# 6             Hospital_expenditure  18.912264
# 7  NUmber_of_past_hospitalizations  15.974474
# 8                     Anual_Salary  25.322480

# %%
insurance=insurance.drop('num_of_steps',axis=1)

# %%
#after dropping the variance inflation factor of age the Vif  of other columns  also changes since they are correlated with each other ,we have to do this repittive process till we get Vif <6 and these are actual  independent columns
#that we can use for model building purposes for higher accuracy

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for col in insurance.columns:
  if((insurance[col].dtype!='object')& (col!='charges')):
    col_list.append(col)

X=insurance[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#                            feature        VIF
# 0                              age  10.155052
# 1                              bmi  11.727204
# 2                         children   1.934095
# 3                     Claim_Amount   6.372297
# 4               past_consultations   7.564379
# 5             Hospital_expenditure  18.779195
# 6  NUmber_of_past_hospitalizations  13.870372
# 7                     Anual_Salary  25.300524

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for col in insurance.columns:
  if((insurance[col].dtype!='object')& (col!='charges')):
    col_list.append(col)

X=insurance[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#                 feature        VIF
# 0                   age   8.391874
# 1                   bmi  11.509066
# 2              children   1.816714
# 3          Claim_Amount   6.198913
# 4    past_consultations   7.453016
# 5  Hospital_expenditure  17.572335
# 6          Anual_Salary  20.169867

# %%
insurance=insurance.drop('Hospital_expenditure',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for col in insurance.columns:
  if((insurance[col].dtype!='object')& (col!='charges')):
    col_list.append(col)

X=insurance[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#               feature        VIF
# 0                 age   8.346663
# 1                 bmi  11.287266
# 2            children   1.813662
# 3        Claim_Amount   6.174285
# 4  past_consultations   7.370116
# 5        Anual_Salary   2.191709

# %%
insurance=insurance.drop('age',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for col in insurance.columns:
  if((insurance[col].dtype!='object')& (col!='charges')):
    col_list.append(col)

X=insurance[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#               feature       VIF
# 0                 bmi  7.899055
# 1            children  1.804596
# 2        Claim_Amount  5.996781
# 3  past_consultations  7.075603
# 4        Anual_Salary  2.174892

# %%
insurance=insurance.drop('bmi',axis=1)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for col in insurance.columns:
  if((insurance[col].dtype!='object')& (col!='charges')):
    col_list.append(col)

X=insurance[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
print(vif_data)
# Out:
#               feature       VIF
# 0            children  1.730701
# 1        Claim_Amount  4.193336
# 2  past_consultations  5.020376
# 3        Anual_Salary  2.044015

# %%
X.columns
# Out:
# Index(['children', 'Claim_Amount', 'past_consultations', 'Anual_Salary'], dtype='object')

# %%
insurance=insurance.drop('NUmber_of_past_hospitalizations',axis=1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X=insurance.loc[:, ['children', 'Claim_Amount', 'past_consultations', 'Anual_Salary']]
y=insurance.iloc[:,-1]

# %%
X
# Out:
#       children  Claim_Amount  past_consultations  Anual_Salary
# 0          0.0   29087.54313                17.0  5.578497e+07
# 1          0.0   39053.67437                 7.0  1.370089e+07
# 2          0.0   39023.62759                19.0  7.352311e+07
# 3          0.0   28185.39332                11.0  7.581968e+07
# 4          0.0   14697.85941                16.0  2.301232e+07
# ...        ...           ...                 ...           ...
# 1333       0.0   63142.25346                32.0  3.101107e+09
# 1334       1.0   43419.95227                31.0  3.484216e+09
# 1335       3.0   52458.92353                25.0  3.640807e+09
# 1336       0.0   69927.51664                34.0  4.006359e+09
# 1337       0.0   63982.80926                31.0  4.117197e+09
#
# [1338 rows x 4 columns]

# %%
y
# Out:
# 0        1121.87390
# 1        1131.50660
# 2        1135.94070
# 3        1136.39940
# 4        1137.01100
#            ...
# 1333    55135.40209
# 1334    58571.07448
# 1335    60021.39897
# 1336    62592.87309
# 1337    63770.42801
# Name: charges, Length: 1338, dtype: float64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#       children  Claim_Amount  past_consultations  Anual_Salary
# 508        2.0  21949.640820                15.0  6.593671e+07
# 563        2.0  44495.915250                14.0  1.592889e+08
# 364        5.0  52472.541650                11.0  3.143569e+07
# 289        3.0  32592.553010                20.0  5.570944e+07
# 1074       0.0  51234.015520                27.0  5.247590e+08
# ...        ...           ...                 ...           ...
# 778        3.0  51074.754970                21.0  2.050006e+08
# 1163       3.0  51434.299840                21.0  8.173708e+08
# 445        0.0   7330.361507                 7.0  5.501141e+07
# 1029       0.0  51178.098110                20.0  3.504584e+08
# 662        0.0  31951.899450                12.0  1.463992e+08
#
# [1070 rows x 4 columns]

# %%
l_model=LinearRegression()

# %%
l_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=l_model.predict(X_test)

# %%
from sklearn.metrics import *

# %%
accuracy=r2_score(y_test,y_pred)

# %%
print('Accuracy of the model',accuracy)   #if any model accuracy is more than 75% the model is considered a good model
# Out:
# Accuracy of the model 0.9035626004242115

# %%
# in my system this is creating random state ,in someone else system this is creating 80 percent and in somene else system different set of 80 % for that we use fixed random state so that different accuracy don't come

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.regplot(x=y_pred,y=y_test)
plt.xlabel('Predicted_Value')
plt.ylabel('Actual_Value')
plt.title('Regression Plot')
plt.show()
