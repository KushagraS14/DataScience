# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('housing.csv')

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df_duplicates=df[df.duplicated()]

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
(df['waterfront']!=0).value_counts()     #ans 163
# Out:
# waterfront
# False    21450
# True       163
# Name: count, dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['price'].max()
# Out:
# 7700000

# %%
df[df['price']==df['price'].max()]     #ans(B)98102
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 7252  6762700020  20141013T000000  7700000         6        8.0        12050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
#
# [1 rows x 21 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df[df['grade']==10]                                #ANS(B) 1134
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 66     3394100030  20140909T000000   975000         4       2.50         2720
# 75     3276920270  20141105T000000   832500         4       4.00         3430
# 79     1531000030  20150323T000000   720000         4       2.50         3450
# 91     5036300431  20150311T000000  1099880         5       2.75         3520
# 108    1853000400  20150305T000000   680000         4       2.50         3140
# ...           ...              ...      ...       ...        ...          ...
# 21568   524059330  20150130T000000  1700000         4       3.50         3830
# 21573  8562790760  20140520T000000   785000         4       3.50         3070
# 21576  9253900271  20150107T000000  3567000         5       4.50         4850
# 21593  8672200110  20150317T000000  1088000         5       3.75         4170
# 21597   191100405  20150421T000000  1575000         4       3.25         3410
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.isnull().value_counts()
# Out:
# id     date   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view   condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  lat    long   sqft_living15  sqft_lot15
# False  False  False  False     False      False        False     False   False       False  False      False  False       False          False     False         False    False  False  False          False         21613
# Name: count, dtype: int64

# %%
df.value_counts()                              #ans (C) 0
# Out:
# id          date             price   bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  lat      long      sqft_living15  sqft_lot15
# 1000102     20140916T000000  280000  6         3.00       2400         9373      2.0     0           0     3          7      2400        0              1991      0             98002    47.3262  -122.214  2060           7316          1
# 6324000090  20150511T000000  210000  2         1.00       990          8140      1.0     0           0     1          6      990         0              1910      0             98116    47.5828  -122.382  2150           5000          1
# 6329000380  20140619T000000  319950  2         1.00       920          8341      1.0     0           0     3          7      920         0              1939      0             98146    47.5015  -122.380  2330           9792          1
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df[df['id']==9126100861]      #ans (B)No
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      9126100861  20141013T000000  221900         3       1.00         1180
# 1      9126100861  20141209T000000  538000         3       2.25         2570
# 2      9126100861  20150225T000000  180000         2       1.00          770
# 3      9126100861  20141209T000000  604000         4       3.00         1960
# 4      9126100861  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608  9126100861  20140521T000000  360000         3       2.50         1530
# 21609  9126100861  20150223T000000  400000         4       2.50         2310
# 21610  9126100861  20140623T000000  402101         2       0.75         1020
# 21611  9126100861  20150116T000000  400000         3       2.50         1600
# 21612  9126100861  20141015T000000  325000         2       0.75         1020
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  9126100861  20141013T000000  221900         3       1.00         1180
# 1  9126100861  20141209T000000  538000         3       2.25         2570
# 2  9126100861  20150225T000000  180000         2       1.00          770
# 3  9126100861  20141209T000000  604000         4       3.00         1960
# 4  9126100861  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df[df['view']==3]          #ans 510 (C)
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 15     9126100861  20150124T000000   650000         4       3.00         2950
# 60     9126100861  20141210T000000   650000         3       2.25         2150
# 114    9126100861  20141028T000000   480000         4       2.50         3230
# 153    9126100861  20150401T000000  2250000         4       3.25         5180
# 216    9126100861  20150221T000000  1505000         5       3.00         3300
# ...           ...              ...      ...       ...        ...          ...
# 21327  9126100861  20150304T000000   535000         4       3.25         2840
# 21344  9126100861  20140822T000000  1488000         5       6.00         6880
# 21505  9126100861  20140617T000000  1555000         3       3.50         4360
# 21539  9126100861  20150219T000000   338500         3       2.25         1333
# 21540  9126100861  20150113T000000  1881583         5       3.50         4410
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['price'].min()                 #ans (C)75000
# Out:
# 75000

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df[df['price']==df['price'].min()]      #(B) ans98022
# Out:
#               id             date  price  bedrooms  bathrooms  sqft_living  \
# 1149  9126100861  20150217T000000  75000         1        0.0          670
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1149     43377     1.0           0     0  ...      3         670
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 1149              0      1966             0    98022  47.2638 -121.906
#
#       sqft_living15  sqft_lot15
# 1149           1160       42882
#
# [1 rows x 21 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df[df['sqft_living']==df['sqft_living'].max()]      #ans(A)98053 zip code
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 12777  9126100861  20140505T000000  2280000         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 12777    307752     3.0           0     4  ...     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 12777           4130      1999             0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 12777           4850      217800
#
# [1 rows x 21 columns]

# %%
df['sqft_living'].max()
# Out:
# 13540

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  9126100861  20141013T000000  221900         3       1.00         1180
# 1  9126100861  20141209T000000  538000         3       2.25         2570
# 2  9126100861  20150225T000000  180000         2       1.00          770
# 3  9126100861  20141209T000000  604000         4       3.00         1960
# 4  9126100861  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df[df['price']==df['price'].max()]      #ans D)1910
# Out:
#               id             date    price  bedrooms  bathrooms  sqft_living  \
# 7252  9126100861  20141013T000000  7700000         6        8.0        12050
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252     27600     2.5           0     3  ...     13        8570
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252           3480      1910          1987    98102  47.6298 -122.323
#
#       sqft_living15  sqft_lot15
# 7252           3940        8800
#
# [1 rows x 21 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
pd.Series.dtype                                                   #D(All oftheabove)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# ans (A)Seriesdata type

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ansC)Index

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ans D)ALL OFTHEABOVE

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ans B)Columns

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def increase(df):
  if (df['sqft_basement']>0) & (df['sqft_basement']<400) :
    df['grade']=df['grade']+1

  else:
      df['grade']=df['grade']+2

# %%
df.apply(increase(df))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-68-d1cc0860f774> in <cell line: 1>()
# ----> 1 df.apply(increase(df))
#
# <ipython-input-64-8b64a899d069> in increase(df)
#       1 def increase(df):
# ----> 2   if (df['sqft_basement']>0) & (df['sqft_basement']<400) :
#       3     df['grade']=df['grade']+1
#       4
#       5   else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1464     @final
#    1465     def __nonzero__(self) -> NoReturn:
# -> 1466         raise ValueError(
#    1467             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1468             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
#ans(A)data.apply(your_function_name(Arg1))

# %%
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  9126100861  20141013T000000  221900         3       1.00         1180
# 1  9126100861  20141209T000000  538000         3       2.25         2570
# 2  9126100861  20150225T000000  180000         2       1.00          770
# 3  9126100861  20141209T000000  604000         4       3.00         1960
# 4  9126100861  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df[df.duplicated(['id','zipcode','grade'])]  #ans (A)
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 19     9126100861  20150424T000000  230000         3       1.00         1250
# 28     9126100861  20140624T000000  438000         3       1.75         1520
# 31     9126100861  20141201T000000  280000         2       1.50         1190
# 48     9126100861  20150428T000000  450000         3       1.75         1250
# 51     9126100861  20150217T000000  345000         5       2.50         3150
# ...           ...              ...     ...       ...        ...          ...
# 21608  9126100861  20140521T000000  360000         3       2.50         1530
# 21609  9126100861  20150223T000000  400000         4       2.50         2310
# 21610  9126100861  20140623T000000  402101         2       0.75         1020
# 21611  9126100861  20150116T000000  400000         3       2.50         1600
# 21612  9126100861  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
 df.duplicate(subset=['id','zipcode','grade'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-d91268c7b54d> in <cell line: 1>()
# ----> 1 df.duplicate(subset=['id','zipcode','grade'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'duplicate'

# %%
df.duplicated(subset=['id','zipcode','grade'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608     True
# 21609     True
# 21610     True
# 21611     True
# 21612     True
# Length: 21613, dtype: bool

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.iloc[3:6,6:10]    #ans C)data.iloc[3:6,6:10]
# Out:
#    sqft_lot  floors  waterfront  view
# 3      5000     1.0           0     0
# 4      8080     1.0           0     0
# 5    101930     1.0           0     0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.DataFrame({'A':[34, 78, 54], 'B':[12, 67, 43]}, index=['r1', 'r2', 'r3'])

# %%
df
# Out:
#      A   B
# r1  34  12
# r2  78  67
# r3  54  43

# %%
df.loc['r2':'r3']             #ans (B)
# Out:
#      A   B
# r2  78  67
# r3  54  43

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ans (D)All of the above

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df3=pd.read_csv('housing.csv') #ans (A)

# %%
pd.to_datetime(df3['date'])
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
pd.to_datetime(df3['date'], utc=False, dayfirst=True)
# Out:
# <ipython-input-98-255c672ef20e>:1: UserWarning: Parsing dates in %Y%m%dT%H%M%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   pd.to_datetime(df3['date'], utc=False, dayfirst=True)
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %%
 pd.to_datetime(df3['date'])
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21608   2014-05-21
# 21609   2015-02-23
# 21610   2014-06-23
# 21611   2015-01-16
# 21612   2014-10-15
# Name: date, Length: 21613, dtype: datetime64[ns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df3.loc[(df3["yr_built"] < 1980) & (df3['floors'] > 2) & (df3['bedrooms'] > 2)]  #ans B)
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 518    4386700135  20141114T000000  2250000         4       2.25         4760
# 759     770000045  20141024T000000   405600         5       1.50         2830
# 960    7578200310  20141112T000000   650000         4       2.00         2208
# 1296   5458800125  20140514T000000   925000         4       2.50         2190
# 1350   7234600786  20140511T000000   842500         4       2.50         2160
# ...           ...              ...      ...       ...        ...          ...
# 18535  3667500015  20140925T000000   770000         4       3.50         3680
# 18631  1337800665  20140811T000000  1325000         4       3.25         2850
# 19068  6613001241  20140811T000000  1415000         4       3.00         3110
# 19188  7942601475  20140520T000000   345600         5       3.50         2800
# 19272  1337300145  20140721T000000  1800000         4       2.50         3320
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sample_list = [['Carl', 22],
['Martha', 25],
['Calvin', 12],
['Stuart', 15]
]

# %%
pd.DataFrame(sample_list,columns=['Name','Age'])   #ans(C)
# Out:
#      Name  Age
# 0    Carl   22
# 1  Martha   25
# 2  Calvin   12
# 3  Stuart   15

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
sample_dict = {'Cristiano': ['Ronaldo','Man U', 801],
'Lionel': ['Messi','PSG', 758],
'Luis': ['Suarez','Atletico Madrid', 509],
'Robert': ['Lewandowski','Bayern Munich', 527],
'Zlatan': ['Ibrahimovic','AC Milan',553]
}

# %%
df1=pd.DataFrame(sample_dict)              #(B) is the correct answer
df1
# Out:
#   Cristiano Lionel             Luis         Robert       Zlatan
# 0   Ronaldo  Messi           Suarez    Lewandowski  Ibrahimovic
# 1     Man U    PSG  Atletico Madrid  Bayern Munich     AC Milan
# 2       801    758              509            527          553

# %%
df1 = df1.transpose()
df1.reset_index(inplace = True)
df1.columns = ['First Name','Last Name', 'Club', 'Goals']

# %%
df1
# Out:
#   First Name    Last Name             Club Goals
# 0  Cristiano      Ronaldo            Man U   801
# 1     Lionel        Messi              PSG   758
# 2       Luis       Suarez  Atletico Madrid   509
# 3     Robert  Lewandowski    Bayern Munich   527
# 4     Zlatan  Ibrahimovic         AC Milan   553

# %%
df1
# Out:
#   First Name    Last Name             Club Goals
# 0  Cristiano      Ronaldo            Man U   801
# 1     Lionel        Messi              PSG   758
# 2       Luis       Suarez  Atletico Madrid   509
# 3     Robert  Lewandowski    Bayern Munich   527
# 4     Zlatan  Ibrahimovic         AC Milan   553

# %%
df1 = pd.DataFrame(sample_dict)
df1 = df1.transpose()
df1.reset_index(inplace = True)
df1.columns = ['First Name','Last Name', 'Club', 'Goals']
df1

#ans(B) is the correct answer
# Out:
#   First Name    Last Name             Club Goals
# 0  Cristiano      Ronaldo            Man U   801
# 1     Lionel        Messi              PSG   758
# 2       Luis       Suarez  Atletico Madrid   509
# 3     Robert  Lewandowski    Bayern Munich   527
# 4     Zlatan  Ibrahimovic         AC Milan   553

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#(B) is thecorrectanswer

# %%
sample_tuple = ([1, 'one', 3],
[2, 'two', 3],
[3, 'Three', 5],
[4, 'Four', 4],
[5, 'Five', 4])

# %%
pd.DataFrame(sample_tuple, columns=['Number', 'Number_text', 'txtlen'])
# Out:
#    Number Number_text  txtlen
# 0       1         one       3
# 1       2         two       3
# 2       3       Three       5
# 3       4        Four       4
# 4       5        Five       4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#(B) ans

ascending = df3.sort_values('price', ascending=True)
descending = df3.sort_values('price', ascending=False)
ascending
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 1149   3421079032  20150217T000000    75000         1       0.00          670
# 15293    40000362  20140506T000000    78000         2       1.00          780
# 465    8658300340  20140523T000000    80000         1       0.75          430
# 16198  3028200080  20150324T000000    81000         2       1.00          730
# 8274   3883800011  20141105T000000    82000         3       1.00          860
# ...           ...              ...      ...       ...        ...          ...
# 1448   8907500070  20150413T000000  5350000         5       5.00         8000
# 4411   2470100110  20140804T000000  5570000         5       5.75         9200
# 9254   9208900037  20140919T000000  6885000         6       7.75         9890
# 3914   9808700762  20140611T000000  7062500         5       4.50        10040
# 7252   6762700020  20141013T000000  7700000         6       8.00        12050
#
# ...

# %%
descending
# Out:
#                id             date    price  bedrooms  bathrooms  sqft_living  \
# 7252   6762700020  20141013T000000  7700000         6       8.00        12050
# 3914   9808700762  20140611T000000  7062500         5       4.50        10040
# 9254   9208900037  20140919T000000  6885000         6       7.75         9890
# 4411   2470100110  20140804T000000  5570000         5       5.75         9200
# 1448   8907500070  20150413T000000  5350000         5       5.00         8000
# ...           ...              ...      ...       ...        ...          ...
# 8274   3883800011  20141105T000000    82000         3       1.00          860
# 16198  3028200080  20150324T000000    81000         2       1.00          730
# 465    8658300340  20140523T000000    80000         1       0.75          430
# 15293    40000362  20140506T000000    78000         2       1.00          780
# 1149   3421079032  20150217T000000    75000         1       0.00          670
#
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df3.describe()     #(A)ans
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df3.head(2)
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
#
#    sqft_lot15
# 0        5650
# 1        7639
#
# [2 rows x 21 columns]

# %%
df3[25:36]
# Out:
#             id             date   price  bedrooms  bathrooms  sqft_living  \
# 25  1202000200  20141103T000000  233000         3       2.00         1710
# 26  1794500383  20140626T000000  937000         3       1.75         2450
# 27  3303700376  20141201T000000  667000         3       1.00         1400
# 28  5101402488  20140624T000000  438000         3       1.75         1520
# 29  1873100390  20150302T000000  719000         4       2.50         2570
# 30  8562750320  20141110T000000  580500         3       2.50         2320
# 31  2426039314  20141201T000000  280000         2       1.50         1190
# 32   461000390  20140624T000000  687500         4       1.75         2330
# 33  7589200193  20141110T000000  535000         3       1.00         1090
# 34  7955080270  20141203T000000  322500         4       2.75         2060
# 35  9547205180  20140613T000000  696000         3       2.50         2300
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df3.loc[(df3["lat"] == 47.6168) & (df3["long"] == -122.045)]
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 4  1954400510  20150218T000000  510000         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 4        7503
#
# [1 rows x 21 columns]

# %%
#ans(C)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df3['Floor Area']=df3['sqft_living']+df3['sqft_lot']+df3['sqft_above']+df3['sqft_basement']     #B)Ans

# %%
df3
# Out:
#                id             date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900         3       1.00         1180
# 1      6414100192  20141209T000000  538000         3       2.25         2570
# 2      5631500400  20150225T000000  180000         2       1.00          770
# 3      2487200875  20141209T000000  604000         4       3.00         1960
# 4      1954400510  20150218T000000  510000         3       2.00         1680
# ...           ...              ...     ...       ...        ...          ...
# 21608   263000018  20140521T000000  360000         3       2.50         1530
# 21609  6600060120  20150223T000000  400000         4       2.50         2310
# 21610  1523300141  20140623T000000  402101         2       0.75         1020
# 21611   291310100  20150116T000000  400000         3       2.50         1600
# 21612  1523300157  20141015T000000  325000         2       0.75         1020
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-50ab3a66f2a5> in <cell line: 1>()
# ----> 1 df3['Floor Area'] = df3['sqft_living'], df3['sqft_lot'], df3['sqft_basement'],df3['sqft_above']
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3948         else:
#    3949             # set column
# -> 3950             self._set_item(key, value)
#    3951
#    3952     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4141         ensure homogeneity.
#    4142         """
# -> 4143         value = self._sanitize_column(value)
#    4144
#    4145         if (
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4868
#    4869         if is_list_like(value):
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A = pd.DataFrame([['Carl', 22],['Martha', 25],['Calvin', 12],['Stuart', 15]], columns=['Name', 'Age'])
B = pd.DataFrame([['Melvin', 25],['Martha', 34],['Lewis', 32],['Leo', 25]], columns=['Name', 'Age'])

# %%
A
# Out:
#      Name  Age
# 0    Carl   22
# 1  Martha   25
# 2  Calvin   12
# 3  Stuart   15

# %%
B
# Out:
#      Name  Age
# 0  Melvin   25
# 1  Martha   34
# 2   Lewis   32
# 3     Leo   25

# %%
inner=pd.merge(A,B,on='Age',how='inner')
inner
# Out:
#    Name_x  Age  Name_y
# 0  Martha   25  Melvin
# 1  Martha   25     Leo

# %%
outer=pd.merge(A,B,on='Age',how='outer')

# %%
outer
# Out:
#    Name_x  Age  Name_y
# 0    Carl   22     NaN
# 1  Martha   25  Melvin
# 2  Martha   25     Leo
# 3  Calvin   12     NaN
# 4  Stuart   15     NaN
# 5     NaN   34  Martha
# 6     NaN   32   Lewis

# %%
left_outer = pd.merge(A, B, on='Age', how='left_outer')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-152-7830e8b846d9> in <cell line: 1>()
# ----> 1 left_outer = pd.merge(A, B, on='Age', how='left_outer')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     160         validate=validate,
#     161     )
# --> 162     return op.get_result(copy=copy)
#     163
#     164
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in get_result(self, copy)
#     807             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     808
# --> 809         join_index, left_indexer, right_indexer = self._get_join_info()
#     810
#     811         result = self._reindex_and_concat(
#
# ...

# %%
right_outer = pd.merge(A, B, on='Age', how='right_outer')                   #Correct answer is(C)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-153-004489a11bba> in <cell line: 1>()
# ----> 1 right_outer = pd.merge(A, B, on='Age', how='right_outer')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     160         validate=validate,
#     161     )
# --> 162     return op.get_result(copy=copy)
#     163
#     164
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in get_result(self, copy)
#     807             self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     808
# --> 809         join_index, left_indexer, right_indexer = self._get_join_info()
#     810
#     811         result = self._reindex_and_concat(
#
# ...

# %%
left_outer = pd.merge(A, B, on='Age', how='left')
right_outer = pd.merge(A, B, on='Age', how='right')                 #(C)answer

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  int64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df3['sqft_living'].corr(df3['sqft_above'])
# Out:
# 0.876596598681318

# %%
#ans (C)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#ans (A) answer

# %%
df3[(df3["bedrooms"]==df3["bedrooms"].max()) & (df3["view"]==3) & (df3["waterfront"]==1)]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15, Floor Area]
# Index: []
#
# [0 rows x 22 columns]
