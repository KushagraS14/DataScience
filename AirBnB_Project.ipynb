# %%
#Airbnb is a american company that is providing you the houses facility in the rent.

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/AirBnB_Dataset.csv')

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park   2787.0
# 1  2595                             Skylit Midtown Castle   2845.0
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !   4632.0
# 3  3831                   Cozy Entire Floor of Brownstone   4869.0
# 4  5022  Entire Apt: Spacious Studio/Loft by central park   7192.0
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
#id represents the column of house to be in rent
#name represents the name of the house to be in rent
#host_id represents the person who buy that property .That person id.
#host_name gives the name of the host.
#neighbourhood group represents multiple properties that are present in the area.Those properties are created in the groups.Group A is having 5 properties.Group B is having 4 properties and GroupnB is having 5 properties
#neighbourhood is having name is having this propert as neighbourhood
#latitude represents the latitude column of the host
#longitude representslongitude of the column
#room type tell u about the type of room,private room ,public room or entire apartment.
#price represents the price of room.
#minimum nights tells u about the  how many nights the buyer want to stay
#reviews :how many reviews has been given for the property.
#last review:The date for which the last review is filled
#in a month what is the average review we get for this property
#avalability: What is the number of days this property is available

# %%
df.describe()
# Out:
#                  id       host_id     latitude    longitude        price  \
# count  7.391000e+03  7.391000e+03  7391.000000  7391.000000  7390.000000
# mean   2.443569e+06  7.922206e+06    40.729248   -73.950496   167.145873
# std    1.689463e+06  7.639974e+06     0.051749     0.779693   278.992369
# min    2.539000e+03  2.571000e+03    40.508680   -74.239860    10.000000
# 25%    8.227680e+05  1.599930e+06    40.688775   -73.984005    80.000000
# 50%    2.224896e+06  5.076827e+06    40.723220   -73.959300   120.000000
# 75%    4.032019e+06  1.198219e+07    40.763785   -73.943620   185.000000
# max    5.478741e+06  4.139808e+07    40.908040    -7.000000  9999.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count     7390.000000        7390.000000        6567.000000
# mean         8.530717          50.785792           0.897995
# std         29.761734          72.709536           1.133974
# min          1.000000           0.000000           0.010000
# ...

# %%
df.describe().T
# Out:
#                                  count          mean           std  \
# id                              7391.0  2.443569e+06  1.689463e+06
# host_id                         7391.0  7.922206e+06  7.639974e+06
# latitude                        7391.0  4.072925e+01  5.174897e-02
# longitude                       7391.0 -7.395050e+01  7.796928e-01
# price                           7390.0  1.671459e+02  2.789924e+02
# minimum_nights                  7390.0  8.530717e+00  2.976173e+01
# number_of_reviews               7390.0  5.078579e+01  7.270954e+01
# reviews_per_month               6567.0  8.979945e-01  1.133974e+00
# calculated_host_listings_count  7390.0  2.636130e+00  6.907491e+00
# availability_365                7390.0  1.332417e+02  1.383504e+02
#
#                                        min           25%           50%  \
# id                              2539.00000  8.227680e+05  2.224896e+06
# host_id                         2571.00000  1.599930e+06  5.076827e+06
# ...

# %%
#we have object type , numerical type and categorical type

# %%
df.describe(include=('O'))
# Out:
#                                     name host_name neighbourhood_group  \
# count                               7384      7386                7391
# unique                              7345      3020                   5
# top     Loft Suite @ The Box House Hotel   Michael           Manhattan
# freq                                  11        79                3420
#
#        neighbourhood        room_type last_review
# count           7391             7390        6567
# unique           163                3        1408
# top     Williamsburg  Entire home/apt  2019-06-23
# freq             696             4417         192

# %%
df.describe(include='all').T
# Out:
#                                  count unique  \
# id                              7391.0    NaN
# name                              7384   7345
# host_id                         7391.0    NaN
# host_name                         7386   3020
# neighbourhood_group               7391      5
# neighbourhood                     7391    163
# latitude                        7391.0    NaN
# longitude                       7391.0    NaN
# room_type                         7390      3
# price                           7390.0    NaN
# minimum_nights                  7390.0    NaN
# number_of_reviews               7390.0    NaN
# last_review                       6567   1408
# reviews_per_month               6567.0    NaN
# calculated_host_listings_count  7390.0    NaN
# availability_365                7390.0    NaN
#
#                                                              top  freq  \
# id                                                           NaN   NaN
# ...

# %%
df.info() # it describes all different data types that has been present  non-null values and the data type that has been present.and the type of data that is present and number of times it was there.
#name column will have some null values
# We can t drop the null values because if we drop the null values we would not be able to visualise the data,make insights
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7391 entries, 0 to 7390
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7391 non-null   int64
#  1   name                            7384 non-null   object
#  2   host_id                         7391 non-null   int64
#  3   host_name                       7386 non-null   object
#  4   neighbourhood_group             7391 non-null   object
#  5   neighbourhood                   7391 non-null   object
#  6   latitude                        7391 non-null   float64
#  7   longitude                       7391 non-null   float64
#  8   room_type                       7390 non-null   object
#  9   price                           7390 non-null   float64
#  10  minimum_nights                  7390 non-null   float64
#  11  number_of_reviews               7390 non-null   float64
# ...

# %%
df.isna()
# Out:
#           id   name  host_id  host_name  neighbourhood_group  neighbourhood  \
# 0      False  False    False      False                False          False
# 1      False  False    False      False                False          False
# 2      False  False    False      False                False          False
# 3      False  False    False      False                False          False
# 4      False  False    False      False                False          False
# ...      ...    ...      ...        ...                  ...            ...
# 43422  False  False    False      False                False          False
# 43423  False  False    False      False                False          False
# 43424  False  False    False      False                False          False
# 43425  False  False    False      False                False          False
# 43426  False  False     True       True                 True           True
#
# ...

# %%
#it is  difficult to recognise ,how many true values we have in our data.
df.isna().sum()
# Out:
# id                                   0
# name                                16
# host_id                              1
# host_name                           22
# neighbourhood_group                  1
# neighbourhood                        1
# latitude                             1
# longitude                            1
# room_type                            1
# price                                1
# minimum_nights                       1
# number_of_reviews                    1
# last_review                       7374
# reviews_per_month                 7374
# calculated_host_listings_count       1
# availability_365                     1
# dtype: int64

# %%
#numerical type of column we can either use mean,median

# %%
#object ->mode

# %%
df['name']=df['name'].fillna(df['name'].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# id                                    0
# name                              43427
# host_id                               1
# host_name                            22
# neighbourhood_group                   1
# neighbourhood                         1
# latitude                              1
# longitude                             1
# room_type                             1
# price                                 1
# minimum_nights                        1
# number_of_reviews                     1
# last_review                        7374
# reviews_per_month                  7374
# calculated_host_listings_count        1
# availability_365                      1
# dtype: int64

# %%
df['name'].mode()
# Out:
# Series([], Name: name, dtype: object)

# %%
df['host_name']=df['host_name'].fillna(df['host_name'].mode()[0],inplace=True)

# %%
df['reviews_per_month']=df['reviews_per_month'].fillna(df['reviews_per_month'].mean())

# %% [markdown]
# **Perform EDA --clean the data,check the duplicate values and drop it.

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#            id  name   host_id host_name neighbourhood_group   neighbourhood  \
# 0        2539  None      2787      None            Brooklyn      Kensington
# 1        2595  None      2845      None           Manhattan         Midtown
# 2        3647  None      4632      None           Manhattan          Harlem
# 3        3831  None      4869      None            Brooklyn    Clinton Hill
# 4        5022  None      7192      None           Manhattan     East Harlem
# ...       ...   ...       ...       ...                 ...             ...
# 7386  5476046  None  10297692      None            Brooklyn   Crown Heights
# 7387  5476474  None  20318406      None           Manhattan  Hell's Kitchen
# 7388  5477034  None   4687722      None            Brooklyn    Williamsburg
# 7389  5477876  None   1506972      None            Brooklyn      Greenpoint
# 7390  5478741  None  28411613      None           Manhattan         Midtown
#
# ...

# %%
df.head()
# Out:
#      id  name  host_id host_name neighbourhood_group neighbourhood  latitude  \
# 0  2539  None     2787      None            Brooklyn    Kensington  40.64749
# 1  2595  None     2845      None           Manhattan       Midtown  40.75362
# 2  3647  None     4632      None           Manhattan        Harlem  40.80902
# 3  3831  None     4869      None            Brooklyn  Clinton Hill  40.68514
# 4  5022  None     7192      None           Manhattan   East Harlem  40.79851
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.97237     Private room  149.0             1.0                9.0
# 1  -73.98377  Entire home/apt  225.0             1.0               45.0
# 2  -73.94190     Private room  150.0             3.0                0.0
# 3  -73.95976  Entire home/apt   89.0             1.0              270.0
# 4  -73.94399  Entire home/apt   80.0            10.0                9.0
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# ...

# %%
df[df['room_type']=='Private room']# used for filtering out the data
# Out:
#            id  name   host_id host_name neighbourhood_group  \
# 0        2539  None      2787      None            Brooklyn
# 2        3647  None      4632      None           Manhattan
# 6        5121  None      7356      None            Brooklyn
# 7        5178  None      8967      None           Manhattan
# 8        5203  None      7490      None           Manhattan
# ...       ...   ...       ...       ...                 ...
# 7377  5447434  None  28173937      None           Manhattan
# 7378  5451108  None   7159349      None            Brooklyn
# 7384  5470350  None   1340207      None           Manhattan
# 7385  5475870  None  22709931      None           Manhattan
# 7388  5477034  None   4687722      None            Brooklyn
#
#            neighbourhood  latitude  longitude     room_type  price  \
# 0             Kensington  40.64749  -73.97237  Private room  149.0
# 2                 Harlem  40.80902  -73.94190  Private room  150.0
# ...

# %%
#we say a column duplicate  when all columns of a row matches with the other row.

# %% [markdown]
# #**rename the column-'id:'property-'id','name':'property name','number_of_reviews':'total_review','calculated_host_listings_count':'host_listings_count'**

# %%
d={
    'id':'property_id',
    'name':'property_name',
    'number_of_reviews':'total_review',
    'calculated_host_listings':'host_listings_count'
}

# %%
df.rename(columns=d,inplace=True)

# %%
df.columns
# Out:
# Index(['property_id', 'property_name', 'host_id', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'total_review', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# #Drop the last review column from the dataset

# %%
df.drop(['last_review'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['property_id', 'property_name', 'host_id', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude',
#        'room_type', 'price', 'minimum_nights', 'total_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
df2=df.drop(df[df['host_id']==2787].index,inplace=True)

# %% [markdown]
# *   ** how many unique properties we are having in the new york city?
# *   how many neighbourhoods we are having?
#
# *   find totalhosts available in the york?
# *   **

# %%
df2

# %%
df                      #entire dataset is for unique()
# Out:
#        property_id                                      property_name  \
# 1             2595                              Skylit Midtown Castle
# 2             3647                THE VILLAGE OF HARLEM....NEW YORK !
# 3             3831                    Cozy Entire Floor of Brownstone
# 4             5022   Entire Apt: Spacious Studio/Loft by central park
# 5             5099          Large Cozy 1 BR Apartment In Midtown East
# ...            ...                                                ...
# 22054     17744351                1 Bd furnished Bayridge Brooklyn NY
# 22055     17746222  Perfect bedroom. Near Subways Columbia CityCol...
# 22056     17748284  Guest BedRm in quaint NYC neighborhood. NEAR T...
# 22057     17749273                      1 br Woodside - close to LGA!
# 22058     17750238          Great room in a spacious Inwood Apartment
#
#          host_id    host_name neighbourhood_group  neighbourhood  latitude  \
# ...

# %%
df['property_id'].nunique()          #nunique will give you the number of unique values
# Out:
# 22053

# %%
df['neighbourhood'].nunique()
# Out:
# 205

# %%
df['host_id'].nunique()
# Out:
# 18460

# %% [markdown]
# Find out the price distribution with the help of price column

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(x=df['price'])
plt.show()
# Out:
# <ipython-input-33-f1ed4688baae>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['price'])

# %%
df['price'].unique()
# Out:
# array([  225.,   150.,    89.,    80.,   200.,    60.,    79.,   135.,
#           85.,   120.,   140.,   215.,    99.,   190.,   299.,   130.,
#          110.,    44.,   180.,    50.,    52.,    55.,    70.,    35.,
#           40.,    68.,   115.,   151.,   228.,   144.,    69.,    49.,
#          375.,   250.,   275.,   230.,    51.,    65.,   105.,    95.,
#          145.,   285.,    94.,   800.,   131.,    98.,   100.,   125.,
#          175.,   500.,   101.,   220.,    59.,   350.,   199.,   325.,
#          235.,   170.,   400.,    75.,    90.,   185.,    77.,    76.,
#          160.,   195.,   156.,   219.,   475.,   165.,   196.,    83.,
#          123.,   265.,   249.,   121.,    45.,    71.,    64.,   159.,
#          189.,   239.,   305.,   155.,    92.,    36.,    37.,   205.,
#           39.,   390.,   129.,   212.,   124.,   122.,   109.,   575.,
#          229.,   169.,   113.,   179.,   349.,   139.,   650.,    67.,
# ...

# %%
#right skewedgraph,4000,1800 are considered as outliers

# %%
sns.boxplot(df['price'])
# Out:
# <Axes: ylabel='price'>

# %%
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7af5dc062a70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7af5dc0621d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7af5dc062d10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7af5dc060460>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7af5dc060040>],
#  'means': []}

# %%
#q1,q3,iqr,UL,LF

Q1=df['price'].quantile(0.25)
Q3=df['price'].quantile(0.75)

# %%
iqr=Q3-Q1

# %%
Q1
# Out:
# 73.0

# %%
Q3
# Out:
# 175.0

# %%
iqr
# Out:
# 102.0

# %%
upperlevel=Q3+1.5*iqr
lowerlevel=Q1-1.5*iqr

# %%
df[(df['price']<lowerlevel)|(df['price']>upperlevel)]
# Out:
#              id                                               name    host_id  \
# 61        15396                 Sunny & Spacious Chelsea Apartment      60278
# 85        19601                perfect for a family or small group      74303
# 103       23686  2000 SF 3br 2bath West Village private  townhouse      93790
# 114       26933  2 BR / 2 Bath Duplex Apt with patio! East Village      72062
# 121       27659                   3 Story Town House in Park Slope     119588
# ...         ...                                                ...        ...
# 48758  36420289    Rustic Garden House Apt, 2 stops from Manhattan   73211393
# 48833  36450896   Brand New 3-Bed Apt in the Best Location of FiDi   29741813
# 48839  36452721  Massage Spa. Stay overnight. Authors Artist dr...  274079964
# 48842  36453160  LUXURY MANHATTAN PENTHOUSE+HUDSON RIVER+EMPIRE...  224171371
# 48856  36457700  Large 3 bed, 2 bath , garden , bbq , all you need   66993395
#
# ...

# %% [markdown]
# Find the most busiest neighourhood with the help of histogram.

# %%
sns.histplot(x='neighbourhood_group',data=df)
plt.show()
