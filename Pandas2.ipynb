# %%
#topics to be discussed :
#pandas case study
#matplotlib and seaborn
#connectivity with python and sql
#then eda that covers numpy,pandas, matplotlib,seaborn

# %%
#problems accountered in a dataset null values ,duplicate values,incoorrect values

# %%
import numpy as np
import pandas as pd

# %%
#remove null values
#remove duplicate values
#remove incorrect values

# %%
#analysing the data

df=pd.read_csv('data.csv')
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  01-08-2022  110.0       130     409.1
# 1         60  02-08-2022  117.0       145     600.0
# 2         60  03-08-2022  103.0       135     340.0
# 3         45  04-08-2022  109.0       175     282.4
# 4         45  05-08-2022  117.0       148     406.0
# 5         60  06-08-2022  102.0       127     300.0
# 6         60  07-08-2022  110.0       136     374.0
# 7        450  08-08-2022    NaN       134     253.3
# 8         30  09-08-2022  109.0       133     195.1
# 9         60  10-08-2022   98.0       124     269.0
# 10        60  11-08-2022  103.0       147     329.3
# 11        60  12-08-2022  100.0       120     250.7
# 12        60  13-08-2022  106.0       128     345.3
# 13        60  14-08-2022  104.0       132     379.3
# 14        60  15-08-2022   98.0       123     275.0
# 15        60  16-08-2022   98.0       120     215.2
# 16        60  17-08-2022  100.0       120     300.0
# ...

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  01-08-2022  110.0       130     409.1
# 1        60  02-08-2022  117.0       145     600.0
# 2        60  03-08-2022  103.0       135     340.0
# 3        45  04-08-2022  109.0       175     282.4
# 4        45  05-08-2022  117.0       148     406.0

# %%
df.tail()
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#     Duration        Date  Pulse  Maxpulse  Calories
# 26        60  27-08-2022   92.0       118     241.0
# 27        60         NaN  103.0       132       NaN
# 28        60  29-08-2022  100.0       132     280.0
# 29        60  30-08-2022  102.0       129     380.3
# 30        60  30-08-2022  102.0       129     380.3

# %%
df.shape
# Out:
# (31, 5)

# %%
df.info()               # 31 Non null means 0 null values 29 non null values means 2 null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  31 non-null     int64
#  1   Date      30 non-null     object
#  2   Pulse     30 non-null     float64
#  3   Maxpulse  31 non-null     int64
#  4   Calories  29 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 1.3+ KB

# %%
df.loc[:,'Duration':'Pulse']
# Out:
#     Duration        Date  Pulse
# 0         60  01-08-2022  110.0
# 1         60  02-08-2022  117.0
# 2         60  03-08-2022  103.0
# 3         45  04-08-2022  109.0
# 4         45  05-08-2022  117.0
# 5         60  06-08-2022  102.0
# 6         60  07-08-2022  110.0
# 7        450  08-08-2022    NaN
# 8         30  09-08-2022  109.0
# 9         60  10-08-2022   98.0
# 10        60  11-08-2022  103.0
# 11        60  12-08-2022  100.0
# 12        60  13-08-2022  106.0
# 13        60  14-08-2022  104.0
# 14        60  15-08-2022   98.0
# 15        60  16-08-2022   98.0
# 16        60  17-08-2022  100.0
# 17        45  18-08-2022   90.0
# 18       600  19-08-2022  103.0
# 19        45  20-08-2022   97.0
# 20        60  21-08-2022  108.0
# 21        45  22-08-2022  100.0
# 22        60  23-08-2022  130.0
# 23       450  24-08-2022  105.0
# 24        60  25-08-2022  102.0
# 25        60  26-08-2022  100.0
# 26        60  27-08-2022   92.0
# 27        60         NaN  103.0
# ...

# %%
df.loc[[0,2,4]]
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  01-08-2022  110.0       130     409.1
# 2        60  03-08-2022  103.0       135     340.0
# 4        45  05-08-2022  117.0       148     406.0

# %%
df.loc[0]             # loc is more powerful it can take string as well as integer values also
# Out:
# Duration            60
# Date        01-08-2022
# Pulse            110.0
# Maxpulse           130
# Calories         409.1
# Name: 0, dtype: object

# %%
df.iloc[[0,2,4]]                   #iloc will work on integer data types
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  01-08-2022  110.0       130     409.1
# 2        60  03-08-2022  103.0       135     340.0
# 4        45  05-08-2022  117.0       148     406.0

# %%
#check for unique/incorrect  values  in duration column
set(df['Duration'])       #for unique values
# Out:
# {30, 45, 60, 450, 600}

# %%
#retrieve rows which have duration as 450 600

df.loc[(df['Duration']==450)|(df['Duration']==600)]
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 7        450  08-08-2022    NaN       134     253.3
# 18       600  19-08-2022  103.0       123     323.0
# 23       450  24-08-2022  105.0       132     246.0

# %%
df.loc[(df['Duration']==450)& (df['Maxpulse']>130)]
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 7        450  08-08-2022    NaN       134     253.3
# 23       450  24-08-2022  105.0       132     246.0

# %%
df.loc[(df['Duration']==600)&(df['Maxpulse']>135)]
# Out:
# Empty DataFrame
# Columns: [Duration, Date, Pulse, Maxpulse, Calories]
# Index: []

# %%
df.loc[(df['Duration']==400)|(df['Duration']==600)]
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 18       600  19-08-2022  103.0       123     323.0

# %%
df.loc[df['Duration']]
# Out:
# {30, 45, 60, 450, 600}

# %%
df.isnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False   True     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False      True
# 18     False  False  False     False     False
# ...

# %%
df['Calories'].isnull()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6fb9fc28e78c> in <cell line: 1>()
# ----> 1 df['Calories'].isnull()
#
# NameError: name 'df' is not defined

# %%
nan_pulse=df[df['Pulse'].isnull()]
nan_pulse
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-d668765ff69e> in <cell line: 1>()
# ----> 1 nan_pulse=df[df['Pulse'].isnull()]
#       2 nan_pulse
#
# NameError: name 'df' is not defined

# %%
nan_cal=df[df['Calories'].isnull()]
nan_cal
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#     Duration        Date  Pulse  Maxpulse  Calories
# 17        45  18-08-2022   90.0       112       NaN
# 27        60         NaN  103.0       132       NaN

# %%
nan_rows=df[(df['Calories'].isnull())|(df['Pulse'].isnull())|(df['Date'].isnull())]

# %%
df[df.isna().any(axis=1)]
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 7        450  08-08-2022    NaN       134     253.3
# 17        45  18-08-2022   90.0       112       NaN
# 27        60         NaN  103.0       132       NaN

# %%
nan_rows.to_csv('nan_rows.csv')

# %%
#fillna will update the entire dataframe only if............inplace=True
#without inplace=True result is only for viewing the change is not being commited.
#df.fillna(999,inplace=True)

# %%
pulse_mean=np.mean(df['Pulse'])
pulse_mean
np.round(pulse_mean,decimals=2)
# Out:
# 103.93

# %%
df.fillna(pulse_mean,inplace=True)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#     Duration        Date       Pulse  Maxpulse    Calories
# 0         60  01-08-2022  110.000000       130  409.100000
# 1         60  02-08-2022  117.000000       145  600.000000
# 2         60  03-08-2022  103.000000       135  340.000000
# 3         45  04-08-2022  109.000000       175  282.400000
# 4         45  05-08-2022  117.000000       148  406.000000
# 5         60  06-08-2022  102.000000       127  300.000000
# 6         60  07-08-2022  110.000000       136  374.000000
# 7        450  08-08-2022  103.933333       134  253.300000
# 8         30  09-08-2022  109.000000       133  195.100000
# ...

# %%
df_duplicated=df[df.duplicated]

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#     Duration        Date       Pulse  Maxpulse    Calories
# 0         60  01-08-2022  110.000000       130  409.100000
# 1         60  02-08-2022  117.000000       145  600.000000
# 2         60  03-08-2022  103.000000       135  340.000000
# 3         45  04-08-2022  109.000000       175  282.400000
# 4         45  05-08-2022  117.000000       148  406.000000
# 5         60  06-08-2022  102.000000       127  300.000000
# 6         60  07-08-2022  110.000000       136  374.000000
# 7        450  08-08-2022  103.933333       134  253.300000
# 8         30  09-08-2022  109.000000       133  195.100000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  30 non-null     int64
#  1   Date      29 non-null     object
#  2   Pulse     29 non-null     float64
#  3   Maxpulse  30 non-null     int64
#  4   Calories  28 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.5+ KB

# %%
#correction in the duration column
for row in df.itertuples():
  if df.at[row.Index,'Duration']==450:
    df.at[row.Index,'Duration']=45
  elif df.at[row.Index,'Duration']==600:
    df.at[row.Index,'Duration']=60

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  01-08-2022  110.0       130     409.1
# 1         60  02-08-2022  117.0       145     600.0
# 2         60  03-08-2022  103.0       135     340.0
# 3         45  04-08-2022  109.0       175     282.4
# 4         45  05-08-2022  117.0       148     406.0
# 5         60  06-08-2022  102.0       127     300.0
# 6         60  07-08-2022  110.0       136     374.0
# 7         45  08-08-2022    NaN       134     253.3
# 8         30  09-08-2022  109.0       133     195.1
# 9         60  10-08-2022   98.0       124     269.0
# 10        60  11-08-2022  103.0       147     329.3
# ...

# %%
df.at[27,'Date']='28-08-2022'
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  01-08-2022  110.0       130     409.1
# 1         60  02-08-2022  117.0       145     600.0
# 2         60  03-08-2022  103.0       135     340.0
# 3         45  04-08-2022  109.0       175     282.4
# 4         45  05-08-2022  117.0       148     406.0
# 5         60  06-08-2022  102.0       127     300.0
# 6         60  07-08-2022  110.0       136     374.0
# 7         45  08-08-2022    NaN       134     253.3
# 8         30  09-08-2022  109.0       133     195.1
# 9         60  10-08-2022   98.0       124     269.0
# 10        60  11-08-2022  103.0       147     329.3
# 11        60  12-08-2022  100.0       120     250.7
# 12        60  13-08-2022  106.0       128     345.3
# 13        60  14-08-2022  104.0       132     379.3
# 14        60  15-08-2022   98.0       123     275.0
# 15        60  16-08-2022   98.0       120     215.2
# 16        60  17-08-2022  100.0       120     300.0
# ...

# %%
df['Total_pulse']=(df['Pulse']+df['Maxpulse'])/2
df
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#     Duration        Date  Pulse  Maxpulse  Calories  Total_pulse  total_pulse
# 0         60  01-08-2022  110.0       130     409.1        120.0        120.0
# 1         60  02-08-2022  117.0       145     600.0        131.0        131.0
# 2         60  03-08-2022  103.0       135     340.0        119.0        119.0
# 3         45  04-08-2022  109.0       175     282.4        142.0        142.0
# 4         45  05-08-2022  117.0       148     406.0        132.5        132.5
# 5         60  06-08-2022  102.0       127     300.0        114.5        114.5
# 6         60  07-08-2022  110.0       136     374.0        123.0        123.0
# ...

# %%
df.at[7,'total_pulse']=97

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  01-08-2022  110.0       130     409.1
# 1         60  02-08-2022  117.0       145     600.0
# 2         60  03-08-2022  103.0       135     340.0
# 3         45  04-08-2022  109.0       175     282.4
# 4         45  05-08-2022  117.0       148     406.0
# 5         60  06-08-2022  102.0       127     300.0
# 6         60  07-08-2022  110.0       136     374.0
# 7        450  08-08-2022    NaN       134     253.3
# 8         30  09-08-2022  109.0       133     195.1
# 9         60  10-08-2022   98.0       124     269.0
# 10        60  11-08-2022  103.0       147     329.3
# ...

# %%
#drop the new column

# %%
df=df.drop(['total_pulse'],axis='columns')

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/lida/components/summarizer.py:74: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   cast_date_col = pd.to_datetime(df[column], errors='coerce')
#     Duration        Date  Pulse  Maxpulse  Calories  Total_pulse
# 0         60  01-08-2022  110.0       130     409.1        120.0
# 1         60  02-08-2022  117.0       145     600.0        131.0
# 2         60  03-08-2022  103.0       135     340.0        119.0
# 3         45  04-08-2022  109.0       175     282.4        142.0
# 4         45  05-08-2022  117.0       148     406.0        132.5
# 5         60  06-08-2022  102.0       127     300.0        114.5
# 6         60  07-08-2022  110.0       136     374.0        123.0
# 7        450  08-08-2022    NaN       134     253.3          NaN
# 8         30  09-08-2022  109.0       133     195.1        121.0
# ...

# %%
#dropping rows starting at index
df=df.drop(df.index[20:])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Duration     20 non-null     int64
#  1   Date         20 non-null     object
#  2   Pulse        19 non-null     float64
#  3   Maxpulse     20 non-null     int64
#  4   Calories     19 non-null     float64
#  5   Total_pulse  19 non-null     float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 1.1+ KB

# %%
#to read xls file install openpyxl
! pip install openpyxl

# %%
df_xlsx=pd.read_excel('data_xlsx.xlsx')

# %%
df_xlsx
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  21-08-2022    108       131     364.2
# 1        45  22-08-2022    100       119     282.0
# 2        60  23-08-2022    130       101     300.0
# 3        45  24-08-2022    105       132     246.0
# 4        60  25-08-2022    102       126     334.5
# 5        60  26-08-2022    100       120     250.0
# 6        60  27-08-2022     92       118     241.0
# 7        60  28-08-2022    103       132     311.3
# 8        60  29-08-2022    100       132     280.0
# 9        60  30-08-2022    102       129     380.3

# %%
df=df.append(df_xlsx)
df
# Out:
# <ipython-input-62-b7f7912b7228>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(df_xlsx)
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  01-08-2022  110.0       130     409.1
# 1         60  02-08-2022  117.0       145     600.0
# 2         60  03-08-2022  103.0       135     340.0
# 3         45  04-08-2022  109.0       175     282.4
# 4         45  05-08-2022  117.0       148     406.0
# 5         60  06-08-2022  102.0       127     300.0
# 6         60  07-08-2022  110.0       136     374.0
# 7        450  08-08-2022    NaN       134     253.3
# 8         30  09-08-2022  109.0       133     195.1
# 9         60  10-08-2022   98.0       124     269.0
# 10        60  11-08-2022  103.0       147     329.3
# 11        60  12-08-2022  100.0       120     250.7
# 12        60  13-08-2022  106.0       128     345.3
# ...

# %%
df.loc[0]
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  01-08-2022  110.0       130     409.1
# 0        60  21-08-2022  108.0       131     364.2

# %%
df.drop(['level_0'],axis='columns',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-d1d8b5a27580> in <cell line: 1>()
# ----> 1 df.drop(['level_0'],axis='columns',inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df=df.reset_index()
df
# Out:
#     index  Duration        Date  Pulse  Maxpulse  Calories
# 0       0        60  01-08-2022  110.0       130     409.1
# 1       1        60  02-08-2022  117.0       145     600.0
# 2       2        60  03-08-2022  103.0       135     340.0
# 3       3        45  04-08-2022  109.0       175     282.4
# 4       4        45  05-08-2022  117.0       148     406.0
# 5       5        60  06-08-2022  102.0       127     300.0
# 6       6        60  07-08-2022  110.0       136     374.0
# 7       7       450  08-08-2022    NaN       134     253.3
# 8       8        30  09-08-2022  109.0       133     195.1
# 9       9        60  10-08-2022   98.0       124     269.0
# 10     10        60  11-08-2022  103.0       147     329.3
# 11     11        60  12-08-2022  100.0       120     250.7
# 12     12        60  13-08-2022  106.0       128     345.3
# 13     13        60  14-08-2022  104.0       132     379.3
# 14     14        60  15-08-2022   98.0       123     275.0
# ...

# %%
df.to_csv('dump.csv',index=False)
#concat command

# %%
#frames=[df1,df2,df3]
#pd.concat(frames,axis=1)

# %%
#joins
df_emp=pd.read_excel('Emp_1.xlsx')
df_yos=pd.read_excel('Emp_Yos.xlsx')

# %%
pd.merge(df_emp,df_yos,on='EmpID' )
# Out:
#    EmpID    Name   Location  Age  YearsOf Service
# 0  E5651   Payal       Pune   35               10
# 1  E5652  Edvina  Bangalore   30                5
# 2  E5653   Madan  Bangalore   45               17
# 3  E5654  Rafeal    Chennai   40               12

# %%
pd.merge(df_emp,df_yos,on='EmpID',how='left' )
# Out:
#    EmpID    Name   Location  Age  YearsOf Service
# 0  E5651   Payal       Pune   35             10.0
# 1  E5652  Edvina  Bangalore   30              5.0
# 2  E5653   Madan  Bangalore   45             17.0
# 3  E5654  Rafeal    Chennai   40             12.0
# 4  E5655   Gopal    Chennai   32              NaN

# %%
pd.merge(df_emp,df_yos,on='EmpID',how='right' )
# Out:
#    EmpID    Name   Location   Age  YearsOf Service
# 0  E5651   Payal       Pune  35.0               10
# 1  E5652  Edvina  Bangalore  30.0                5
# 2  E5653   Madan  Bangalore  45.0               17
# 3  E5654  Rafeal    Chennai  40.0               12
# 4  E5656     NaN        NaN   NaN                7

# %%
pd.merge(df_emp,df_yos,on='EmpID',how='outer' )
# Out:
#    EmpID    Name   Location   Age  YearsOf Service
# 0  E5651   Payal       Pune  35.0             10.0
# 1  E5652  Edvina  Bangalore  30.0              5.0
# 2  E5653   Madan  Bangalore  45.0             17.0
# 3  E5654  Rafeal    Chennai  40.0             12.0
# 4  E5655   Gopal    Chennai  32.0              NaN
# 5  E5656     NaN        NaN   NaN              7.0

# %%
df_grade=pd.read_excel('/Emp_Grade1.xlsx')

# %%
EMP_GRADE=pd.merge(df_emp,df_grade,left_on='EmpID',right_on='ID')
# Out:
#    EmpID    Name   Location  Age     ID Grade
# 0  E5651   Payal       Pune   35  E5651     A
# 1  E5652  Edvina  Bangalore   30  E5652     B
# 2  E5653   Madan  Bangalore   45  E5653     C
# 3  E5654  Rafeal    Chennai   40  E5654     D

# %%
#Merge 3 datasets
df_grade2=pd.read_excel('/Emp_Grade2.xlsx')

# %%
df_grade2
# Out:
#    EmpID Grade
# 0  E5651     A
# 1  E5652     B
# 2  E5653     C
# 3  E5654     D
# 4  E5656     E

# %%
df_emp
# Out:
#    EmpID    Name   Location  Age
# 0  E5651   Payal       Pune   35
# 1  E5652  Edvina  Bangalore   30
# 2  E5653   Madan  Bangalore   45
# 3  E5654  Rafeal    Chennai   40
# 4  E5655   Gopal    Chennai   32

# %%
df_grade
# Out:
#       ID Grade
# 0  E5651     A
# 1  E5652     B
# 2  E5653     C
# 3  E5654     D
# 4  E5656     E
